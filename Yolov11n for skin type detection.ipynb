# %%
# !nvidia-smi
# Out:
# Tue Dec 10 10:15:32 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.48 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.8/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="dQwmLcyTg3ETRVtr8Lie")
project = rf.workspace("new-workspace").project("skin-classifier-test")
version = project.version(1)
dataset = version.download("folder")
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4f1bb263bb91> in <cell line: 9>()
#       7 rf = Roboflow(api_key="dQwmLcyTg3ETRVtr8Lie")
#       8 project = rf.workspace("new-workspace").project("skin-classifier-test")
# ----> 9 version = project.version(v1)
#      10 dataset = version.download("folder")
#      11
#
# NameError: name 'v1' is not defined

# %%
# Load YOLOv8n-cls, train it on mnist160 for 3 epochs and predict an image with it

model = YOLO('yolov8n-cls.pt')  # load a pretrained YOLOv8n classification model
model.train(data='dataset.location', epochs=3)  # train the model

# %%
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %%
# !unzip /content/Skin_classifier_test.v1i.folder.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#    creating: test/Acne/
#    creating: test/Acne Oily-Skin/
#    creating: test/Acne Oily-Skin Skin-Redness/
#    creating: test/Acne Oily-Skin Skin-Redness Wrinkles/
#  extracting: test/Acne Oily-Skin Skin-Redness Wrinkles/acne-prone-skin_180_jpeg_jpg.rf.2afee6afeab78d29254a67add7ea56b6.jpg
#  extracting: test/Acne Oily-Skin Skin-Redness/01F3MMZ6PBPZ02R00D2GS0XSDQ_jpeg_jpg.rf.e48ef195be579a26d2baa0eefa492897.jpg
#  extracting: test/Acne Oily-Skin Skin-Redness/acne-2-_jpg.rf.a33a0774e1be8df5ec7b69cf1c8ceef6.jpg
#  extracting: test/Acne Oily-Skin Skin-Redness/acne-prone-skin_164_jpeg_jpg.rf.ff3513acbbd052b6841be20819bfd7e2.jpg
#  extracting: test/Acne Oily-Skin Skin-Redness/acne3_jpg.rf.2fed80fdc8d4530c2487fc00b3ff7d02.jpg
#    creating: test/Acne Oily-Skin Wrinkles/
#  extracting: test/Acne Oily-Skin Wrinkles/01F3MMX85MKKVDR2PMR3S2F4B6_jpeg_jpg.rf.53d8043dd3bfea071954d8ca47230654.jpg
# ...

# %%
from ultralytics import YOLO

#loading classification model
model = YOLO('yolo11n-cls.pt')

#train the model
results = model.train(data='/content/Skin_classifier_test.v1i.folder', epochs=20, imgsz=640)
# Out:
# ...
# 100%|██████████| 5.52M/5.52M [00:00<00:00, 100MB/s]
# Ultralytics 8.3.48 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
